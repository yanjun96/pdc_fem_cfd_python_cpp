# %% [markdown]
# # Lab2

# %%
from IPython.display import display
from PIL import Image

# %% [markdown]
# ## Quesiton 1

# %%
img = Image.open("size_10.png")  # Open image
display(img)  # Display image in Jupyter
img2 = Image.open("size_100.png")
display(img2)
img3 = Image.open("size_100_no_c.png")
display(img3)
display(Image.open("size_20_central.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %% [markdown]
# Small size is much easy to find boundary, large one has lots errors.

# %% [markdown]
# ## Quesiton 2
# The first figure is polynominal with p = 2.
# The second figure

# %%
img4 = Image.open("size_10_poly.png")
display(img4)
img5 = Image.open("size_10_rbf.png")
display(img5)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %% [markdown]
# ## Quesiton 3
# for rbf first, sigma = 1 and sigma = 5
# img7 is when sigma = 0.5, the variance is small, but the bias increases.

# %%
img6 = Image.open("size_30_rbf_sigma1.png")
display(img6)
img7 = Image.open("size_30_rbf_sigma0.5.png")
display(img7)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %%
display( Image.open("size_30_polu_p2.png") )
display( Image.open("size_30_polu_p5.png") )
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %% [markdown]
# ## Quesiton 4
# lower c can tolerate more noise

# %%
display( Image.open("size_30_poly_c_0.1.png") )
display( Image.open("size_30_poly_c_100.png") )
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %% [markdown]
# ## Quesiton 5

# %% [markdown]
# more slack:
# 1: if the model is already complexed, like higher polynominal order.
#
# 2: if the decison boundary is linear, then more slack.
#
# 3: for large dataset, more slcak, complex model is computational expensive.
