# %%
from IPython.display import display
from PIL import Image

# %% [markdown]
# # Assignment 1

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
# Open the image
img = Image.open("1.png")
img_resized = img.resize((img.width // 3, img.height // 3))
plt.imshow(img_resized)
plt.axis("off")  # Hide axes
plt.show()

# %% [markdown]
# # Assignment 3
#
# when varialble is little, like 3, can assume feature independence. while like 10 variables, it is difficult to assume.
#
#  full covariance matrices

# %%
# Open the image
img = Image.open("iris.png")
img_resized = img.resize((img.width // 2, img.height // 2))
plt.imshow(img_resized)
plt.axis("off")  # Hide axes
plt.show()

# %%
img = Image.open("vowel.png")
img_resized = img.resize((img.width // 2, img.height //2 ))
plt.imshow(img_resized)
plt.axis("off")  # Hide axes
plt.show()

# %% [markdown]
# # Assignment 5
#
# 1: has improvement
#
# 2: boundary is more precise
#
# 3: Yes, here use boosting is efficient, the accuracy is nearyly 94%.

# %%
img = Image.open("bayes_1.png")
img_resized = img.resize((img.width // 2, img.height //2 ))
plt.imshow(img_resized)
plt.axis("off")  # Hide axes
plt.show()

# %% [markdown]
# # Assignment 6
#
# 1: Boosting decision tree has improved for iris classify, but not as good as Bayesian.
#
# 2: The boundary is more precise but not as good as Bayesian.
#
# 3: For decision tree, maybe a more advanced model is suitable for iris since boosting does not work very well. It also very slow for calculation.

# %%
img = Image.open("decision_2.png")
img_resized = img.resize((img.width // 2, img.height //2 ))
plt.imshow(img_resized)
plt.axis("off")  # Hide axes
plt.show()

# %% [markdown]
# # Assignment 7

# %% [markdown]
# 1: outliers:
# naive Bayes is less sensitive since it based on probality, low probality does not count. Decision tree is influenced by outliers since it will create a new leaf. As for boost, dependes on basic filter.

# %% [markdown]
# 2: Irrelevant input: naive Bayes is poorly predict since it has probality accounted to these input. It will affect others. Decison tree: can neglect since information gain is large. Adabost may be the best.

# %% [markdown]
# 3: naive Bayes: simple and power, but performed not as best as complicated model. Decision tree: often overfitting. best choice is boosting decision trees. Combine weaker classifier to a strong one.

# %% [markdown]
# 4: naive Bayes is good at binary, since Bernoulli Naive Bayes. categorical data, all is good. Continue features, may be decision tree is more suitable, for example, speed larger than 100 km/h, naive Bayes need have a normal distribution. But decision tree only need a choice.

# %% [markdown]
# 5: For large dimension, naive Bayes is best since it Instead of modelling one D-dimensional distribution, it modelling D one-dimensional distributions. Decision tree has dimension curse.
